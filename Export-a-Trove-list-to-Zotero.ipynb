# %%
TROVE_ZOTERO_MAPPINGS = {
    'Art work': 'artwork',
    'Article': 'journalArticle',
    'Article/Book chapter': 'bookSection',
    'Article/Conference paper': 'conferencePaper',
    'Article/Journal or magazine article': 'journalArticle',
    'Article/Other article': 'journalArticle',
    'Article/Report': 'report',
    'Article/Review': 'journalArticle',
    'Article/Working paper': 'report',
    'Audio book': 'book',
    'Book': 'book',
    'Book/Braille': 'book',
    'Book/Illustrated': 'book',
    'Book/Large print': 'book',
    'Conference Proceedings': 'book',
    'Data set': 'computerProgram',
    'Map': 'map',
    'Map/Aerial photograph': 'map',
    'Map/Atlas': 'map',
    'Map/Braille': 'map',
    'Map/Electronic': 'map',
    'Map/Globe or object': 'map',
    'Map/Large print': 'map',
    'Map/Map series': 'map',
    'Map/Microform': 'map',
    'Map/Single map': 'map',
    'Object': 'artwork',
    'Periodical': 'book',
    'Periodical/Journal, magazine, other': 'book',
    'Periodical/Newspaper': 'book',
    'Photograph': 'artwork',
    'Poster, chart, other': 'artwork',
    'Published': 'document',
    'Sheet music': 'document',
    'Sound': 'audioRecording',
    'Sound/Interview, lecture, talk': 'audioRecording',
    'Sound/Other sound': 'audioRecording',
    'Sound/Recorded music': 'audioRecording',
    'Thesis': 'thesis',
    'Unpublished': 'manuscript',
    'Video': 'videoRecording',
    'Video/Captioned': 'videoRecording'
}

FIELD_MAPPINGS = {
    #Not including common fields that have multiple values
    # contributor -> creator
    # tags -> tags
    # subject -> tags
    'journalArticle': { 
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'isPartOf': 'publicationTitle',
        'language': 'language',
        'abstract': 'abstractNote',
        'pagination': 'pages',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'book': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'publisher',
        'edition': 'edition',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'bookSection': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'isPartOf': 'bookTitle',
        'language': 'language',
        'abstract': 'abstractNote',
        'pagination': 'pages',
        'publisher': 'publisher',
        'edition': 'edition',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'conferencePaper': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'isPartOf': 'proceedingsTitle',
        'language': 'language',
        'abstract': 'abstractNote',
        'pagination': 'pages',
        'publisher': 'publisher',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'report': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'institution',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'thesis': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'university',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'artwork': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'language': 'language',
        'abstract': 'abstractNote',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'map': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'publisher',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'computerProgram': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'abstract': 'abstractNote',
        'publisher': 'company',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'document': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'publisher',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'manuscript': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'language': 'language',
        'abstract': 'abstractNote',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'audioRecording': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'isPartOf': 'seriesTitle',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'label',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'videoRecording': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'isPartOf': 'seriesTitle',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'studio',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'encyclopediaArticle': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'isPartOf': 'encyclopediaTitle',
        'language': 'language',
        'abstract': 'abstractNote',
        'publisher': 'publisher',
        'repository': 'archive',
        'rights': 'rights',
        'source': 'libraryCatalog'
    },
    'webpage': {
        'title': 'title',
        'troveUrl': 'url',
        'issued': 'date',
        'isPartOf': 'websiteTitle',
        'language': 'language',
        'abstract': 'abstractNote',
        'rights': 'rights'
    }
}

# %%
import datetime
from urllib.parse import urlparse, urlsplit
import requests
import os.path
import tempfile
import copy
from pyzotero import zotero
from trove import Trove



def guess_zotero_type(item_type):
    '''
    Check mappings to try and find a zotero type.
    '''
    if isinstance(item_type, list):
        item_type = item_type[0]
    try:
        zotero_type = TROVE_ZOTERO_MAPPINGS[item_type]
    except KeyError:
        zotero_type = 'journalArticle'
    return zotero_type


def process_name(name):
    '''
    Try and do some cleaning of names that have dates included.
    '''
    parts = name.split(',')
    if len(parts) > 1:
        family_name = parts[0]
        other_names = parts[1]
    else:
        family_name = parts[0]
        other_names = ''
    return {'family_name': family_name, 'other_names': other_names}


def extract_filename_from_url(url):
    '''
    Try and get the filename of attachments.
    '''
    filename = os.path.basename(urlsplit(url).path)
    if '.' not in filename:
        filename = None
    return filename


def prepare_attachment(trove_api, url, default):
    '''
    Save a local copy of attachment, and return the local file path.
    '''
    response = requests.get(url)
    filename = extract_filename_from_url(url)
    if not filename:
        filename = default
    folder = tempfile.gettempdir()
    filename = os.path.join(folder, filename)
    with open(filename, 'wb') as attachment:
        attachment.write(response.content)
    return filename


def prepare_tags(tags):
    '''
    Takes a list of tags and formats in the object format expected by Zotero.
    '''
    return [{'tag': tag} for tag in tags]


def create_zotero_object(zotero_api, trove_api, record):
    '''
    Process Trove record to populate fields in Zotero item template.
    '''
    attachments = []
    item_type = list(record.keys())[0]
    item = record[item_type]
    if item_type == 'work':
        zotero_type = guess_zotero_type(item['type'])
        zotero_template = zotero_api.item_template(zotero_type)
        template = copy.deepcopy(zotero_template)
        work = trove_api.get_item(item_id=item['id'], item_type='work')
        details = work.get_details()
        fields = FIELD_MAPPINGS[zotero_type]
        for t_field, z_field in fields.items():
            if t_field in details:
                template[z_field] = '; '.join(details[t_field])
        if 'contributor' in details:
            for index, contributor in enumerate(details['contributor']):
                names = process_name(contributor)
                template['creators'][index]['firstName'] = names['other_names']
                template['creators'][index]['lastName'] = names['family_name']
        tags = work.get_all_tags()
        if 'subject' in details:
            tags.extend(details['subject'])
        if tags:
            template['tags'] = prepare_tags(tags)
        source = work.get_repository()
        repository = None
        if source['nuc']:
            contributor = trove_api.get_item(item_id=source['nuc'], item_type='contributor')
            repository = contributor.get_title()
        elif source['repository']:
            repository = source['repository']
        if repository:
            template['archive'] = repository
        urls = work.get_urls()
        if 'mediumresolution' in urls:
            image_url = urls['mediumresolution']
        elif 'thumbnail' in urls:
            image_url = urls['thumbnail']
        else:
            image_url = None
        if image_url:
            attachments.append(prepare_attachment(trove_api, image_url, 'image.jpg'))
        pdf_url = work.get_pdf_url()
        if pdf_url:
            attachments.append(prepare_attachment(trove_api, pdf_url, 'article.pdf'))
        
    elif item_type == 'people':
        zotero_type = 'encyclopediaArticle'
        template = zotero_api.item_template(zotero_type)
        template['title'] = 'Trove party record'
        template['url'] = item['troveUrl']

    elif item_type == 'article':
        zotero_type = 'newspaperArticle'
        template = zotero_api.item_template(zotero_type)
        template['title'] = item['heading']
        template['url'] = 'http://nla.gov.au/nla.news-article' + item['id']
        template['publicationTitle'] = item['title']['value']
        template['pages'] = item['page']
        template['date'] = item['date']
        pdf_url = 'http://trove.nla.gov.au/ndp/del/printArticlePdf/{}/3'.format(item['id'])
        response = requests.get(pdf_url)
        with open('article.pdf', 'wb') as pdf:
            pdf.write(response.content)
        attachments.append('article.pdf')

    elif item_type == 'externalWebsite':
        zotero_type = 'webpage'
        template = zotero_api.item_template(zotero_type)
        template['title'] = item['title']
        template['url'] = item['identifier']['value']

    if template['itemType'] != 'webpage':
        template['libraryCatalog'] = 'Trove'
    template['accessDate'] = datetime.datetime.now().date().isoformat()
    return {'zotero_item': template, 'attachments': attachments}


def create_zotero_collection(zotero_api, collection_name):
    '''
    Creates a Zotero collection with the given name,
    then retrieves the key for that collection.
    '''
    collection_key = None
    if collection_name:
        created = zotero_api.create_collections([{'name': collection_name}])
        if created:
            collections = zotero_api.collections(q=collection_name)
            try:
                collection_key = collections[0]['key']
            except (IndexError, KeyError):
                print('Error retrieving collection key.')
        else:
            print('Error creating collection.')
    return collection_key


def check_duplicate_collection(zotero_api, collection_name):
    '''
    Check to see if a collection with the supplied name already exists.
    '''
    collections = zotero_api.collections(q=collection_name)
    if collections:
        collection_key = collections[0]['key']
    else:
        collection_key = None
    return collection_key


def check_duplicate_item(zotero_api, current_item):
    '''
    Check to see if a Zotero item with the name and url of the supplied Trove item
    already exists.
    '''
    print(current_item)
    z_item = None
    if 'heading' in current_item:
        title = current_item['heading']
        url = 'http://nla.gov.au/nla.news-article' + current_item['id']
    else:
        try:
            title = current_item['title']
            url = current_item['troveUrl']
        except KeyError:
            url = current_item['troveUrl']
            if '/people/' in url:
                title = 'Trove Party Record'
            else:
                title = None
    if title and url:
        items = zotero_api.items(q=title)
        for item in items:
            # print(item)
            if item['data']['url'] == url:
                z_item = item
                break
    return z_item


def export_list(list_id, zotero_api, trove_api):
    #zotero_items = []
    trove_list = trove_api.get_item(item_id=list_id, item_type='list')
    list_name = '{} (Trove list: {})'.format(trove_list.get_title(), list_id)
    print(list_name)
    collection_key = check_duplicate_collection(zotero_api, list_name)
    if not collection_key:
        collection_key = create_zotero_collection(zotero_api, list_name)
    if collection_key:
        for item in trove_list.list_items:
            print(item)
            if 'deleted' not in item:
                z_item = check_duplicate_item(zotero_api, list(item.values())[0])
                if not z_item:
                    details = create_zotero_object(zotero_api, trove_api, item)
                    zotero_item = details['zotero_item']
                    zotero_item['collections'] = [collection_key]
                    response = zotero_api.create_items([zotero_item])
                    print(response)
                    #print response
                    if details['attachments']:
                        zotero_api.attachment_simple(details['attachments'], response['successful']['0']['key'])
                    print('New item added: {}'.format(zotero_item['title']))
                else:
                    # zotero_api.addto_collection(collection_key, [z_item])
                    print(z_item)
                    z_item['collections'] = [collection_key]
                    zotero_api.update_item(z_item['data'])
                    print('Item updated: {}'.format(z_item['data']['title']))
            #zot.addto_collection(collection_key, resp)
            #zotero_items.append(zotero_item.copy())
        #Can't get the adding of multiple items to work
        #And check_items fails
        #zot.check_items(zotero_items)
        #resp = zot.create_items(zotero_items)
        #zot.addto_collection(collection_key, resp)

# %%
zot_api = zotero.Zotero('', 'user', '')

# %%
trove_api = Trove('')

# %%
export_list('83777', zot_api, trove_api)
# Out:
# Clement Wragge (Trove list: 83777)
# {'work': {'id': '153942274', 'url': '/work/153942274', 'troveUrl': 'http://trove.nla.gov.au/work/153942274', 'title': 'Clement Wragge, 1899', 'contributor': ['Nicholas, Sir Harold'], 'issued': 1899, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/134400'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=185373&custom_att_2=simple_viewer'}]}}
# {'id': '153942274', 'url': '/work/153942274', 'troveUrl': 'http://trove.nla.gov.au/work/153942274', 'title': 'Clement Wragge, 1899', 'contributor': ['Nicholas, Sir Harold'], 'issued': 1899, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/134400'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=185373&custom_att_2=simple_viewer'}]}
# {'key': 'JUC3WUFU', 'version': 9475, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/JUC3WUFU', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/JUC3WUFU', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Nicholas', 'parsedDate': '1899', 'numChildren': 1}, 'data': {'key': 'JUC3WUFU', 'version': 9475, 'itemType': 'artwork', 'title': 'Clement Wragge, 1899', 'creators': [{'creatorType': 'artist', 'firstName': 'Sir Harold', 'lastName': 'Nicholas'}], 'abstractNote': "Clement Lindley Wragge, meteorologist, was born 18 September 1852 at Stourbridge, Worcestershire, England. Orphaned in early childhood, Wragge was educated at Uttoxeter Grammar School in Staffordshire and articled to a London solicitor. In 1876 he joined the South Australian surveyor-general's department. Wragge studied meteorology and in 1878 returned to Britain where he established weather observation stations. He founded similar stations in South Australia and founded the Meteorological Society of Australasia in 1886. In January 1887 he was appointed meteorological observer in the Queensland post and telegraph department. Wragge expanded the observation network, issued forecasts, pioneered research into tropical revolving storms in the south-west Pacific, lectured extensively and built an observatory at his Taringa home. After advocating the creation of a national weather bureau he was bitterly disappointed in 1907 when H.A. Hunt was appointed head of the Commonwealth Meteorological Bureau. Wragge moved to Auckland, New Zealand, where he built an observatory. He revisited Queensland in 1913 but failed to win support for his proposed tropical cyclone research centre. He died following a stroke at Birkenhead, New Zealand on 10 December 1922. (Information taken from: Australian dictionary of biography, v.12, 1990) Picture taken by Sir Harold Nicholas of Anstelle(?), September 1899, on the occasion of Mr Wragge's visit to lecture at Lismore, New South Wales. (Description supplied with photograph). An article about his lecture appears in the Northern Star (Lismore, NSW : 1876-1954) Wednesday 13 September 1899, p 4.", 'artworkMedium': '', 'artworkSize': '', 'date': '1899', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/153942274', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'Wragge, Clement'}, {'tag': 'meteorologists'}, {'tag': 'portraits'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:05:26Z', 'dateModified': '2019-04-08T11:05:26Z'}}
# Item updated: Clement Wragge, 1899
# {'deleted': 'deleted', 'value': 'The resource described by this item has been deleted from Trove'}
# {'work': {'id': '36904481', 'url': '/work/36904481', 'troveUrl': 'http://trove.nla.gov.au/work/36904481', 'title': 'Cartoon of the meteorologist, Clement Wragge', 'contributor': ['Unidentified'], 'type': ['Art work'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/126973'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=108654&custom_att_2=simple_viewer'}]}}
# {'id': '36904481', 'url': '/work/36904481', 'troveUrl': 'http://trove.nla.gov.au/work/36904481', 'title': 'Cartoon of the meteorologist, Clement Wragge', 'contributor': ['Unidentified'], 'type': ['Art work'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/126973'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=108654&custom_att_2=simple_viewer'}]}
# No such field!
# No such field!
# {'successful': {'0': {'key': '5EX78BV3', 'version': 9477, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/5EX78BV3', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/5EX78BV3', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Unidentified', 'numChildren': 0}, 'data': {'key': '5EX78BV3', 'version': 9477, 'itemType': 'artwork', 'title': 'Cartoon of the meteorologist, Clement Wragge', 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'Unidentified'}], 'abstractNote': 'Caption on cartoon: A typical contemporary cartoon of Wragge, whose Queensland weather forecasts were written in a style glittering with metaphors and classical allusions.', 'artworkMedium': '', 'artworkSize': '', 'date': '', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/36904481', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'cartoons'}, {'tag': 'meteorologists'}, {'tag': 'weather forecasting'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:32:25Z', 'dateModified': '2019-04-08T11:32:25Z'}}}, 'success': {'0': '5EX78BV3'}, 'unchanged': {}, 'failed': {}}
# New item added: Cartoon of the meteorologist, Clement Wragge
# {'work': {'id': '153923228', 'url': '/work/153923228', 'troveUrl': 'http://trove.nla.gov.au/work/153923228', 'title': 'Cartoon of meteorologist, Clement Wragge, 1906', 'contributor': ['Unidentified'], 'issued': 1906, 'type': ['Art work'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/130356'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=111934&custom_att_2=simple_viewer'}]}}
# {'id': '153923228', 'url': '/work/153923228', 'troveUrl': 'http://trove.nla.gov.au/work/153923228', 'title': 'Cartoon of meteorologist, Clement Wragge, 1906', 'contributor': ['Unidentified'], 'issued': 1906, 'type': ['Art work'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/130356'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=111934&custom_att_2=simple_viewer'}]}
# No such field!
# {'successful': {'0': {'key': '7RU3J6EU', 'version': 9480, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/7RU3J6EU', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/7RU3J6EU', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Unidentified', 'parsedDate': '1906', 'numChildren': 0}, 'data': {'key': '7RU3J6EU', 'version': 9480, 'itemType': 'artwork', 'title': 'Cartoon of meteorologist, Clement Wragge, 1906', 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'Unidentified'}], 'abstractNote': "Caption on cartoon: Arrangements are now being made by the Minister for Home Affairs to give effect to the Act recently passed to establish a Federal Meteorological Bureau. All things being equal, preference will, however, naturally be given to an applicant for the post of Commonwealth Meteorologist who is already resident in Australia. - News par. Clement (musing): I'm on the spot, anyhow; and surely my marvellous meteorological researches in the atmospheric cumulii in Queensland, my unparalleled rhodomontadii in the Australian press, my poetic lucubrations in weather reports, and my portentous prophecies in regard to the precarious precipitation of moisture - surely these can no longer go unrecognised? Clement Wragge, on the 26th September 1902, arranged for six Stiger Vortex guns to be fired into the clouds above Charleville in the hope of breaking the drought. When informed of the failure of the experiment Wragge was in no doubt who was to blame. 'I could not manage to stay at Charleville until a favourable opportunity of making the experiments occurred' he explained, 'and, of course, if the Charleville people will not carry out my instructions, I cannot help it'. (Information taken from Brisbane Courier, 29 September 1902, p.5)", 'artworkMedium': '', 'artworkSize': '', 'date': '1906', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/153923228', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'cartoons'}, {'tag': 'meteorologists'}, {'tag': 'rain-making equipment'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:32:33Z', 'dateModified': '2019-04-08T11:32:33Z'}}}, 'success': {'0': '7RU3J6EU'}, 'unchanged': {}, 'failed': {}}
# New item added: Cartoon of meteorologist, Clement Wragge, 1906
# {'work': {'id': '153919175', 'url': '/work/153919175', 'troveUrl': 'http://trove.nla.gov.au/work/153919175', 'title': 'Meteorologist, Clement Wragge, at home in his tropical garden at Taringa, Brisbane, ca. 1902', 'contributor': ['Unidentified'], 'issued': 1902, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/133685'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=112502&custom_att_2=simple_viewer'}]}}
# {'id': '153919175', 'url': '/work/153919175', 'troveUrl': 'http://trove.nla.gov.au/work/153919175', 'title': 'Meteorologist, Clement Wragge, at home in his tropical garden at Taringa, Brisbane, ca. 1902', 'contributor': ['Unidentified'], 'issued': 1902, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/133685'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=112502&custom_att_2=simple_viewer'}]}
# No such field!
# {'successful': {'0': {'key': 'EADHE3DF', 'version': 9483, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/EADHE3DF', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/EADHE3DF', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Unidentified', 'parsedDate': '1902', 'numChildren': 0}, 'data': {'key': 'EADHE3DF', 'version': 9483, 'itemType': 'artwork', 'title': 'Meteorologist, Clement Wragge, at home in his tropical garden at Taringa, Brisbane, ca. 1902', 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'Unidentified'}], 'abstractNote': "Caption on photograph: Our meteorologist at home - Mr Wragge in his tropical garden at Capemba. Capemba was the name of Wragge's residence in Taringa.", 'artworkMedium': '', 'artworkSize': '', 'date': '1902', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/153919175', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'gardens'}, {'tag': 'meteorologists'}, {'tag': 'tropical plants'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:32:42Z', 'dateModified': '2019-04-08T11:32:42Z'}}}, 'success': {'0': 'EADHE3DF'}, 'unchanged': {}, 'failed': {}}
# New item added: Meteorologist, Clement Wragge, at home in his tropical garden at Taringa, Brisbane, ca. 1902
# {'work': {'id': '183567207', 'url': '/work/183567207', 'troveUrl': 'http://trove.nla.gov.au/work/183567207', 'title': 'Autograph letter signed from John Howard Lidgett Cumpston, Forrest, Camberra, A.C.T. to the Mitchell Library, 9 November 1945 describing a bicycle and hiking trip he made with other university students to the Clement Wragge Hut, Mt. Kosciusko in 1901; with two photographs', 'contributor': ['Cumpston, J. H. L. (John Howard Lidgett), 1880-1954'], 'issued': 1945, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://acms.sl.nsw.gov.au/item/itemDetailPaged.aspx?itemID=950197'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://acms.sl.nsw.gov.au/_DAMt/image/22/126/a5831005t.jpg'}]}}
# {'id': '183567207', 'url': '/work/183567207', 'troveUrl': 'http://trove.nla.gov.au/work/183567207', 'title': 'Autograph letter signed from John Howard Lidgett Cumpston, Forrest, Camberra, A.C.T. to the Mitchell Library, 9 November 1945 describing a bicycle and hiking trip he made with other university students to the Clement Wragge Hut, Mt. Kosciusko in 1901; with two photographs', 'contributor': ['Cumpston, J. H. L. (John Howard Lidgett), 1880-1954'], 'issued': 1945, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://acms.sl.nsw.gov.au/item/itemDetailPaged.aspx?itemID=950197'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://acms.sl.nsw.gov.au/_DAMt/image/22/126/a5831005t.jpg'}]}
# No such field!
# No such field!
# {'successful': {'0': {'key': '5TPCRPCD', 'version': 9486, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/5TPCRPCD', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/5TPCRPCD', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Cumpston', 'parsedDate': '1945', 'numChildren': 0}, 'data': {'key': '5TPCRPCD', 'version': 9486, 'itemType': 'artwork', 'title': 'Autograph letter signed from John Howard Lidgett Cumpston, Forrest, Camberra, A.C.T. to the Mitchell Library, 9 November 1945 describing a bicycle and hiking trip he made with other university students to the Clement Wragge Hut, Mt. Kosciusko in 1901; with two photographs', 'creators': [{'creatorType': 'artist', 'firstName': 'J. H. L. (John Howard Lidgett)', 'lastName': 'Cumpston'}], 'abstractNote': '', 'artworkMedium': '', 'artworkSize': '', 'date': '1945', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of NSW.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/183567207', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'Mitchell Library (N.S.W.)'}, {'tag': 'Wragge, Clement L. (Clement Lindley), 1852-1922'}, {'tag': 'Wragges Observatory Hut (N.S.W.)'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:32:52Z', 'dateModified': '2019-04-08T11:32:52Z'}}}, 'success': {'0': '5TPCRPCD'}, 'unchanged': {}, 'failed': {}}
# New item added: Autograph letter signed from John Howard Lidgett Cumpston, Forrest, Camberra, A.C.T. to the Mitchell Library, 9 November 1945 describing a bicycle and hiking trip he made with other university students to the Clement Wragge Hut, Mt. Kosciusko in 1901; with two photographs
# {'work': {'id': '153932753', 'url': '/work/153932753', 'troveUrl': 'http://trove.nla.gov.au/work/153932753', 'title': "Clement Wragge's home on Swann Road, Taringa, Brisbane, ca. 1901", 'contributor': ['Unidentified'], 'issued': 1901, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/138788'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=74386&custom_att_2=simple_viewer'}]}}
# {'id': '153932753', 'url': '/work/153932753', 'troveUrl': 'http://trove.nla.gov.au/work/153932753', 'title': "Clement Wragge's home on Swann Road, Taringa, Brisbane, ca. 1901", 'contributor': ['Unidentified'], 'issued': 1901, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/138788'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=74386&custom_att_2=simple_viewer'}]}
# No such field!
# {'successful': {'0': {'key': 'A6MU8FZW', 'version': 9489, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/A6MU8FZW', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/A6MU8FZW', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Unidentified', 'parsedDate': '1901', 'numChildren': 0}, 'data': {'key': 'A6MU8FZW', 'version': 9489, 'itemType': 'artwork', 'title': "Clement Wragge's home on Swann Road, Taringa, Brisbane, ca. 1901", 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'Unidentified'}], 'abstractNote': 'Clement Wragge was Queensland Government Meteorologist from 1887 - 1903.', 'artworkMedium': '', 'artworkSize': '', 'date': '1901', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/153932753', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'dogs'}, {'tag': 'fences'}, {'tag': 'suburbs'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:33:02Z', 'dateModified': '2019-04-08T11:33:02Z'}}}, 'success': {'0': 'A6MU8FZW'}, 'unchanged': {}, 'failed': {}}
# New item added: Clement Wragge's home on Swann Road, Taringa, Brisbane, ca. 1901
# {'work': {'id': '192577925', 'url': '/work/192577925', 'troveUrl': 'http://trove.nla.gov.au/work/192577925', 'title': 'Wragges Observatory 1897', 'contributor': ['graham scully'], 'issued': 1897, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'https://www.flickr.com/photos/34925962@N03/3314783333'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'https://farm4.staticflickr.com/3425/3314783333_06aa48eeb3_t.jpg'}]}}
# {'id': '192577925', 'url': '/work/192577925', 'troveUrl': 'http://trove.nla.gov.au/work/192577925', 'title': 'Wragges Observatory 1897', 'contributor': ['graham scully'], 'issued': 1897, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'https://www.flickr.com/photos/34925962@N03/3314783333'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'https://farm4.staticflickr.com/3425/3314783333_06aa48eeb3_t.jpg'}]}
# No such field!
# {'successful': {'0': {'key': 'GHUERK97', 'version': 9492, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/GHUERK97', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/GHUERK97', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'graham scully', 'parsedDate': '1897', 'numChildren': 0}, 'data': {'key': 'GHUERK97', 'version': 9492, 'itemType': 'artwork', 'title': 'Wragges Observatory 1897', 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'graham scully'}], 'abstractNote': '4 December 1897, the first day on the summit of Mount Kosciuszko. Clement Wragge in centre in front of tent, James Spencer, guide, on left with hand on horses head.Contributor: Graham ScullyFormat: black and white photo by Charles KerryDigital copy by G ScullyNSW Map number and name: Perisher Valley No 8525 - 2SGPS ref(WGS84) E 55613223 N 5964734Collection of: Original photo in collection of Henry Willis, a descendant of James Spencer.Digital copy in collection of G ScullyDate photo taken 4 December 1897.', 'artworkMedium': '', 'artworkSize': '', 'date': '1897', 'language': 'English', 'shortTitle': '', 'archive': 'Flickr.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/192577925', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': '1897-12-01 00:00:00'}, {'tag': 'meterology'}, {'tag': 'science'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:33:12Z', 'dateModified': '2019-04-08T11:33:12Z'}}}, 'success': {'0': 'GHUERK97'}, 'unchanged': {}, 'failed': {}}
# New item added: Wragges Observatory 1897
# {'deleted': 'deleted', 'value': 'The resource described by this item has been deleted from Trove'}
# {'work': {'id': '36895120', 'url': '/work/36895120', 'troveUrl': 'http://trove.nla.gov.au/work/36895120', 'title': 'Crowd of people watching a small explosion of a Vortex Gun, Mount Morgan, 1902', 'contributor': ['Unidentified'], 'issued': 1902, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/142818'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=81041&custom_att_2=simple_viewer'}]}}
# {'id': '36895120', 'url': '/work/36895120', 'troveUrl': 'http://trove.nla.gov.au/work/36895120', 'title': 'Crowd of people watching a small explosion of a Vortex Gun, Mount Morgan, 1902', 'contributor': ['Unidentified'], 'issued': 1902, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/142818'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=81041&custom_att_2=simple_viewer'}]}
# No such field!
# {'successful': {'0': {'key': 'CD27GZ47', 'version': 9495, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/CD27GZ47', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/CD27GZ47', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Unidentified', 'parsedDate': '1902', 'numChildren': 0}, 'data': {'key': 'CD27GZ47', 'version': 9495, 'itemType': 'artwork', 'title': 'Crowd of people watching a small explosion of a Vortex Gun, Mount Morgan, 1902', 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'Unidentified'}], 'abstractNote': 'In 1902 Clement Wragge set up a Stiger-Vortex gun at Mt. Morgan in order to seed clouds and thus encourage precipitation. (Description taken from John Kerr, Mt Morgan - Gold Copper & Oil, p. 103)', 'artworkMedium': '', 'artworkSize': '', 'date': '1902', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/36895120', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'explosions'}, {'tag': 'meteorological equipment'}, {'tag': 'rain-making equipment'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:33:22Z', 'dateModified': '2019-04-08T11:33:22Z'}}}, 'success': {'0': 'CD27GZ47'}, 'unchanged': {}, 'failed': {}}
# New item added: Crowd of people watching a small explosion of a Vortex Gun, Mount Morgan, 1902
# {'work': {'id': '153914474', 'url': '/work/153914474', 'troveUrl': 'http://trove.nla.gov.au/work/153914474', 'title': 'Rain making equipment, Charleville, 1947', 'contributor': ['Unidentified'], 'issued': 1947, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/96692'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=201533&custom_att_2=simple_viewer'}]}}
# {'id': '153914474', 'url': '/work/153914474', 'troveUrl': 'http://trove.nla.gov.au/work/153914474', 'title': 'Rain making equipment, Charleville, 1947', 'contributor': ['Unidentified'], 'issued': 1947, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/96692'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=201533&custom_att_2=simple_viewer'}]}
# No such field!
# {'successful': {'0': {'key': 'E74PHW5S', 'version': 9498, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/E74PHW5S', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/E74PHW5S', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Unidentified', 'parsedDate': '1947', 'numChildren': 0}, 'data': {'key': 'E74PHW5S', 'version': 9498, 'itemType': 'artwork', 'title': 'Rain making equipment, Charleville, 1947', 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'Unidentified'}], 'abstractNote': "The 'Stiger-Vortex-Gun' was an idea from Professor Clement Wragge, a Queensland meteorologist who had 10 guns build in Brisbane and taken to Charleville in an attempt to break the drought. Guns were then placed in different parts of the town and on 2 September, 1902, gunpowder was emptied into the breech of each gun and then detonated. No rain fell.", 'artworkMedium': '', 'artworkSize': '', 'date': '1947', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/153914474', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'Charleville, 1947'}, {'tag': 'meteorological equipment'}, {'tag': 'rain-making equipment'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:33:31Z', 'dateModified': '2019-04-08T11:33:31Z'}}}, 'success': {'0': 'E74PHW5S'}, 'unchanged': {}, 'failed': {}}
# New item added: Rain making equipment, Charleville, 1947
# {'work': {'id': '153931026', 'url': '/work/153931026', 'troveUrl': 'http://trove.nla.gov.au/work/153931026', 'title': 'Meteorological observatory on Wickham Terrace, Brisbane, ca. 1900', 'contributor': ['Unidentified'], 'issued': 1900, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/140638'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=79721&custom_att_2=simple_viewer'}]}}
# {'id': '153931026', 'url': '/work/153931026', 'troveUrl': 'http://trove.nla.gov.au/work/153931026', 'title': 'Meteorological observatory on Wickham Terrace, Brisbane, ca. 1900', 'contributor': ['Unidentified'], 'issued': 1900, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://hdl.handle.net/10462/deriv/140638'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://bishop.slq.qld.gov.au:80/webclient/DeliveryManager?pid=79721&custom_att_2=simple_viewer'}]}
# No such field!
# {'successful': {'0': {'key': 'ZRD9SGDR', 'version': 9501, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/ZRD9SGDR', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/ZRD9SGDR', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Unidentified', 'parsedDate': '1900', 'numChildren': 0}, 'data': {'key': 'ZRD9SGDR', 'version': 9501, 'itemType': 'artwork', 'title': 'Meteorological observatory on Wickham Terrace, Brisbane, ca. 1900', 'creators': [{'creatorType': 'artist', 'firstName': '', 'lastName': 'Unidentified'}], 'abstractNote': 'Several men are pictured with meteorological equipment and Clement Wragge is in the centre. (Description supplied with photograph) Part of the Brisbane Baptist Tabernacle and a substantial home can be seen in the background.', 'artworkMedium': '', 'artworkSize': '', 'date': '1900', 'language': 'English', 'shortTitle': '', 'archive': 'State Library of Queensland.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/153931026', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'buildings, structures & establishments'}, {'tag': 'meteorological equipment'}, {'tag': 'meteorological stations'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:33:40Z', 'dateModified': '2019-04-08T11:33:40Z'}}}, 'success': {'0': 'ZRD9SGDR'}, 'unchanged': {}, 'failed': {}}
# New item added: Meteorological observatory on Wickham Terrace, Brisbane, ca. 1900
# {'work': {'id': '81015890', 'url': '/work/81015890', 'troveUrl': 'http://trove.nla.gov.au/work/81015890', 'title': 'The first observatory on Kosciuszko, Snowy Mountains, New South Wales, ca. 1897 / Charles Kerry', 'contributor': ['Kerry, Charles H. (Charles Henry), 1857-1928'], 'issued': '1880-1910', 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'linktext': 'National Library of Australia digitised item', 'value': 'http://nla.gov.au/nla.obj-138928148'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://nla.gov.au/nla.obj-138928148-t'}]}}
# {'id': '81015890', 'url': '/work/81015890', 'troveUrl': 'http://trove.nla.gov.au/work/81015890', 'title': 'The first observatory on Kosciuszko, Snowy Mountains, New South Wales, ca. 1897 / Charles Kerry', 'contributor': ['Kerry, Charles H. (Charles Henry), 1857-1928'], 'issued': '1880-1910', 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'linktext': 'National Library of Australia digitised item', 'value': 'http://nla.gov.au/nla.obj-138928148'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://nla.gov.au/nla.obj-138928148-t'}]}
# No such field!
# No such field!
# No such field!
# No such field!
# {'successful': {'0': {'key': 'NI6HVGNT', 'version': 9504, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/NI6HVGNT', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/NI6HVGNT', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Kerry', 'parsedDate': '1880', 'numChildren': 0}, 'data': {'key': 'NI6HVGNT', 'version': 9504, 'itemType': 'artwork', 'title': 'The first observatory on Kosciuszko, Snowy Mountains, New South Wales, ca. 1897 / Charles Kerry', 'creators': [{'creatorType': 'artist', 'firstName': 'Charles H. (Charles Henry)', 'lastName': 'Kerry'}], 'abstractNote': '', 'artworkMedium': '', 'artworkSize': '', 'date': '1880-1910', 'language': '', 'shortTitle': '', 'archive': 'Libraries Australia', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/81015890', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:33:50Z', 'dateModified': '2019-04-08T11:33:50Z'}}}, 'success': {'0': 'NI6HVGNT'}, 'unchanged': {}, 'failed': {}}
# New item added: The first observatory on Kosciuszko, Snowy Mountains, New South Wales, ca. 1897 / Charles Kerry
# {'article': {'id': '162833980', 'url': '/newspaper/162833980', 'heading': 'Clement Wragge at Home.', 'category': 'Article', 'title': {'id': '698', 'value': 'The Sydney Mail and New South Wales Advertiser (NSW : 1871 - 1912)'}, 'date': '1894-09-08', 'page': 491, 'pageSequence': 491, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/162833980'}}
# {'id': '162833980', 'url': '/newspaper/162833980', 'heading': 'Clement Wragge at Home.', 'category': 'Article', 'title': {'id': '698', 'value': 'The Sydney Mail and New South Wales Advertiser (NSW : 1871 - 1912)'}, 'date': '1894-09-08', 'page': 491, 'pageSequence': 491, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/162833980'}
# {'successful': {'0': {'key': '592AJVSK', 'version': 9507, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/592AJVSK', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/592AJVSK', 'type': 'text/html'}}, 'meta': {'parsedDate': '1894-09-08', 'numChildren': 0}, 'data': {'key': '592AJVSK', 'version': 9507, 'itemType': 'newspaperArticle', 'title': 'Clement Wragge at Home.', 'creators': [], 'abstractNote': '', 'publicationTitle': 'The Sydney Mail and New South Wales Advertiser (NSW : 1871 - 1912)', 'place': '', 'edition': '', 'date': '1894-09-08', 'section': '', 'pages': '491', 'language': '', 'shortTitle': '', 'ISSN': '', 'url': 'http://nla.gov.au/nla.news-article162833980', 'accessDate': '2019-04-08', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:34:00Z', 'dateModified': '2019-04-08T11:34:00Z'}}}, 'success': {'0': '592AJVSK'}, 'unchanged': {}, 'failed': {}}
# New item added: Clement Wragge at Home.
# {'article': {'id': '145708725', 'url': '/newspaper/145708725', 'heading': 'Mr. Clement Wragge.', 'category': 'Article', 'title': {'id': '713', 'value': 'Table Talk (Melbourne, Vic. : 1885 - 1939)'}, 'date': '1902-11-20', 'page': 13, 'pageSequence': 13, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/145708725'}}
# {'id': '145708725', 'url': '/newspaper/145708725', 'heading': 'Mr. Clement Wragge.', 'category': 'Article', 'title': {'id': '713', 'value': 'Table Talk (Melbourne, Vic. : 1885 - 1939)'}, 'date': '1902-11-20', 'page': 13, 'pageSequence': 13, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/145708725'}
# {'successful': {'0': {'key': 'PI6SNDDZ', 'version': 9510, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/PI6SNDDZ', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/PI6SNDDZ', 'type': 'text/html'}}, 'meta': {'parsedDate': '1902-11-20', 'numChildren': 0}, 'data': {'key': 'PI6SNDDZ', 'version': 9510, 'itemType': 'newspaperArticle', 'title': 'Mr. Clement Wragge.', 'creators': [], 'abstractNote': '', 'publicationTitle': 'Table Talk (Melbourne, Vic. : 1885 - 1939)', 'place': '', 'edition': '', 'date': '1902-11-20', 'section': '', 'pages': '13', 'language': '', 'shortTitle': '', 'ISSN': '', 'url': 'http://nla.gov.au/nla.news-article145708725', 'accessDate': '2019-04-08', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:34:10Z', 'dateModified': '2019-04-08T11:34:10Z'}}}, 'success': {'0': 'PI6SNDDZ'}, 'unchanged': {}, 'failed': {}}
# New item added: Mr. Clement Wragge.
# {'article': {'id': '87517976', 'url': '/newspaper/87517976', 'heading': 'MR. CLEMENT WRAGGE. DEATH IN NEW ZEALAND', 'category': 'Article', 'title': {'id': '291', 'value': 'Chronicle (Adelaide, SA : 1895 - 1954)'}, 'date': '1922-12-16', 'page': 37, 'pageSequence': 37, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/87517976'}}
# {'id': '87517976', 'url': '/newspaper/87517976', 'heading': 'MR. CLEMENT WRAGGE. DEATH IN NEW ZEALAND', 'category': 'Article', 'title': {'id': '291', 'value': 'Chronicle (Adelaide, SA : 1895 - 1954)'}, 'date': '1922-12-16', 'page': 37, 'pageSequence': 37, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/87517976'}
# {'successful': {'0': {'key': 'FQ3CR5KB', 'version': 9513, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/FQ3CR5KB', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/FQ3CR5KB', 'type': 'text/html'}}, 'meta': {'parsedDate': '1922-12-16', 'numChildren': 0}, 'data': {'key': 'FQ3CR5KB', 'version': 9513, 'itemType': 'newspaperArticle', 'title': 'MR. CLEMENT WRAGGE. DEATH IN NEW ZEALAND', 'creators': [], 'abstractNote': '', 'publicationTitle': 'Chronicle (Adelaide, SA : 1895 - 1954)', 'place': '', 'edition': '', 'date': '1922-12-16', 'section': '', 'pages': '37', 'language': '', 'shortTitle': '', 'ISSN': '', 'url': 'http://nla.gov.au/nla.news-article87517976', 'accessDate': '2019-04-08', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:34:21Z', 'dateModified': '2019-04-08T11:34:21Z'}}}, 'success': {'0': 'FQ3CR5KB'}, 'unchanged': {}, 'failed': {}}
# New item added: MR. CLEMENT WRAGGE. DEATH IN NEW ZEALAND
# {'work': {'id': '9958833', 'url': '/work/9958833', 'troveUrl': 'http://trove.nla.gov.au/work/9958833', 'title': 'Experiences of a meteorologist in South Australia / Clement L. Wragge', 'contributor': ['Wragge, Clement L. (Clement Lindley), 1852-1922'], 'issued': 1980, 'type': ['Book/Illustrated', 'Book'], 'holdingsCount': 14, 'versionCount': 1}}
# {'id': '9958833', 'url': '/work/9958833', 'troveUrl': 'http://trove.nla.gov.au/work/9958833', 'title': 'Experiences of a meteorologist in South Australia / Clement L. Wragge', 'contributor': ['Wragge, Clement L. (Clement Lindley), 1852-1922'], 'issued': 1980, 'type': ['Book/Illustrated', 'Book'], 'holdingsCount': 14, 'versionCount': 1}
# No such field!
# No such field!
# No such field!
# No such field!
# {'successful': {'0': {'key': 'FN566MUP', 'version': 9516, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/FN566MUP', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/FN566MUP', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Wragge', 'parsedDate': '1980', 'numChildren': 0}, 'data': {'key': 'FN566MUP', 'version': 9516, 'itemType': 'book', 'title': 'Experiences of a meteorologist in South Australia / Clement L. Wragge', 'creators': [{'creatorType': 'author', 'firstName': 'Clement L. (Clement Lindley)', 'lastName': 'Wragge'}], 'abstractNote': '', 'series': '', 'seriesNumber': '', 'volume': '', 'numberOfVolumes': '', 'edition': '', 'place': '', 'publisher': 'Warradale, S.Aust. : Pioneer Books,', 'date': '1980', 'numPages': '', 'language': '', 'ISBN': '', 'shortTitle': '', 'url': 'http://trove.nla.gov.au/work/9958833', 'accessDate': '2019-04-08', 'archive': 'Libraries Australia', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:34:31Z', 'dateModified': '2019-04-08T11:34:31Z'}}}, 'success': {'0': 'FN566MUP'}, 'unchanged': {}, 'failed': {}}
# New item added: Experiences of a meteorologist in South Australia / Clement L. Wragge
# {'work': {'id': '11308773', 'url': '/work/11308773', 'troveUrl': 'http://trove.nla.gov.au/work/11308773', 'title': 'The history of Goulburn, N.S.W. / by Ransome T. Wyatt', 'contributor': ['Wyatt, Ransome T. (Ransome Tovey), 1886-1945'], 'issued': '1941-1995', 'type': ['Book', 'Book/Illustrated'], 'holdingsCount': 45, 'versionCount': 8, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'linktext': 'National Library of Australia digitised item', 'value': 'http://nla.gov.au/nla.obj-29899609'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://nla.gov.au/nla.obj-29899609-t'}]}}
# {'id': '11308773', 'url': '/work/11308773', 'troveUrl': 'http://trove.nla.gov.au/work/11308773', 'title': 'The history of Goulburn, N.S.W. / by Ransome T. Wyatt', 'contributor': ['Wyatt, Ransome T. (Ransome Tovey), 1886-1945'], 'issued': '1941-1995', 'type': ['Book', 'Book/Illustrated'], 'holdingsCount': 45, 'versionCount': 8, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'linktext': 'National Library of Australia digitised item', 'value': 'http://nla.gov.au/nla.obj-29899609'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'http://nla.gov.au/nla.obj-29899609-t'}]}
# No such field!
# {'successful': {'0': {'key': 'ZSDW64N5', 'version': 9517, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/ZSDW64N5', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/ZSDW64N5', 'type': 'text/html'}}, 'meta': {'creatorSummary': 'Wyatt', 'parsedDate': '1941', 'numChildren': 0}, 'data': {'key': 'ZSDW64N5', 'version': 9517, 'itemType': 'book', 'title': 'The history of Goulburn, N.S.W. / by Ransome T. Wyatt', 'creators': [{'creatorType': 'author', 'firstName': 'Ransome T. (Ransome Tovey)', 'lastName': 'Wyatt'}], 'abstractNote': "This book describes the history of Goulburn, early history: exploration, early settlement, bushrangers and Aborigines. It also covers its 'modern' history and there is an emphasis on its institutions and services. Forward written by T.P. Manion, Mayor. Illustrations, photographs, biographical notes and index.", 'series': '', 'seriesNumber': '', 'volume': '', 'numberOfVolumes': '', 'edition': '', 'place': '', 'publisher': '', 'date': '1941-1995', 'numPages': '', 'language': 'English', 'ISBN': '', 'shortTitle': '', 'url': 'http://trove.nla.gov.au/work/11308773', 'accessDate': '2019-04-08', 'archive': 'Libraries Australia', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [{'tag': 'Gold rush'}, {'tag': 'Goulburn (N.S.W.)'}, {'tag': 'Pioneers'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:34:38Z', 'dateModified': '2019-04-08T11:34:38Z'}}}, 'success': {'0': 'ZSDW64N5'}, 'unchanged': {}, 'failed': {}}
# New item added: The history of Goulburn, N.S.W. / by Ransome T. Wyatt
# {'article': {'id': '221344158', 'url': '/newspaper/221344158', 'heading': 'WRAGGE', 'category': 'Article', 'title': {'id': '1177', 'value': 'Crookwell Gazette (NSW : 1885 - 1954)'}, 'date': '1903-12-01', 'page': 4, 'pageSequence': 4, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/221344158'}}
# {'id': '221344158', 'url': '/newspaper/221344158', 'heading': 'WRAGGE', 'category': 'Article', 'title': {'id': '1177', 'value': 'Crookwell Gazette (NSW : 1885 - 1954)'}, 'date': '1903-12-01', 'page': 4, 'pageSequence': 4, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/221344158'}
# {'key': '3TC8365G', 'version': 8697, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/3TC8365G', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/3TC8365G', 'type': 'text/html'}}, 'meta': {'parsedDate': '1903-12-01', 'numChildren': 2}, 'data': {'key': '3TC8365G', 'version': 8697, 'itemType': 'newspaperArticle', 'title': 'WRAGGE', 'creators': [], 'abstractNote': 'PACK through the many--far too many : -- late drought stricken years, when mother earth lay gasping like a giant in the last throes of his death agony ...', 'publicationTitle': 'Crookwell Gazette (NSW : 1885 - 1954)', 'place': 'NSW', 'edition': '', 'date': '1 Dec 1903', 'section': '', 'pages': '4', 'language': '', 'shortTitle': '', 'ISSN': '', 'url': 'http://nla.gov.au/nla.news-article221344158', 'accessDate': '2018-04-18T00:35:38Z', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [], 'collections': ['XXHSKJ2R'], 'relations': {}, 'dateAdded': '2018-04-18T00:35:38Z', 'dateModified': '2018-04-18T00:35:38Z'}}
# Item updated: WRAGGE
# {'work': {'id': '208456887', 'url': '/work/208456887', 'troveUrl': 'http://trove.nla.gov.au/work/208456887', 'title': 'Clement Lindley Wragge', 'issued': 1880, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://collections.slsa.sa.gov.au/resource/B+9825'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'https://slsa-collections.s3.amazonaws.com/35/c7/cc3d-db76-52dd-8827-fc048dfc659b.jpg'}]}}
# {'id': '208456887', 'url': '/work/208456887', 'troveUrl': 'http://trove.nla.gov.au/work/208456887', 'title': 'Clement Lindley Wragge', 'issued': 1880, 'type': ['Photograph'], 'holdingsCount': 1, 'versionCount': 1, 'identifier': [{'type': 'url', 'linktype': 'fulltext', 'value': 'http://collections.slsa.sa.gov.au/resource/B+9825'}, {'type': 'url', 'linktype': 'thumbnail', 'value': 'https://slsa-collections.s3.amazonaws.com/35/c7/cc3d-db76-52dd-8827-fc048dfc659b.jpg'}]}
# No such field!
# No such field!
# {'successful': {'0': {'key': '7R88DKJH', 'version': 9521, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/7R88DKJH', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/7R88DKJH', 'type': 'text/html'}}, 'meta': {'parsedDate': '1880', 'numChildren': 0}, 'data': {'key': '7R88DKJH', 'version': 9521, 'itemType': 'artwork', 'title': 'Clement Lindley Wragge', 'creators': [], 'abstractNote': "[General description] Full length portrait of Clement Lindley Wragge, meteorologist. A tall slim man with red hair and quick temper he created controversy in his field. He was the first person to present real weather forecasts in Australia and originated the use of names for weather systems. He is regarded by many as the 'father of modern meteorology'. No known copyright restrictions", 'artworkMedium': '', 'artworkSize': '', 'date': '1880', 'language': 'English; en', 'shortTitle': '', 'archive': 'State Library of South Australia.', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'url': 'http://trove.nla.gov.au/work/208456887', 'accessDate': '2019-04-08', 'rights': '', 'extra': '', 'tags': [{'tag': 'Wragge, Clement L. (Clement Lindley), 1852-1922'}, {'tag': 'c. 1880'}], 'collections': ['N7BZECBI'], 'relations': {}, 'dateAdded': '2019-04-08T11:34:51Z', 'dateModified': '2019-04-08T11:34:51Z'}}}, 'success': {'0': '7R88DKJH'}, 'unchanged': {}, 'failed': {}}
# New item added: Clement Lindley Wragge
# {'article': {'id': '83156754', 'url': '/newspaper/83156754', 'heading': '"WRAGGE."', 'category': 'Article', 'title': {'id': '275', 'value': 'The Daily News (Perth, WA : 1882 - 1950)'}, 'date': '1903-02-05', 'page': 3, 'pageSequence': 3, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/83156754'}}
# {'id': '83156754', 'url': '/newspaper/83156754', 'heading': '"WRAGGE."', 'category': 'Article', 'title': {'id': '275', 'value': 'The Daily News (Perth, WA : 1882 - 1950)'}, 'date': '1903-02-05', 'page': 3, 'pageSequence': 3, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/83156754'}
# {'key': 'FDLLIF89', 'version': 8790, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/FDLLIF89', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/FDLLIF89', 'type': 'text/html'}}, 'meta': {'parsedDate': '1903-02-05', 'numChildren': 2}, 'data': {'key': 'FDLLIF89', 'version': 8790, 'itemType': 'newspaperArticle', 'title': '"WRAGGE."', 'creators': [], 'abstractNote': 'We have received from the editor, Mr. Clement L. "Wragge, the current issue of his meteorological periodical, which contains "many cheerful facts." ...', 'publicationTitle': 'Daily News (Perth, WA : 1882 - 1950)', 'place': 'Perth, WA', 'edition': '', 'date': '5 Feb 1903', 'section': '', 'pages': '3', 'language': '', 'shortTitle': '', 'ISSN': '', 'url': 'http://nla.gov.au/nla.news-article83156754', 'accessDate': '2018-04-13T05:00:10Z', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [], 'collections': ['XXHSKJ2R'], 'relations': {}, 'dateAdded': '2018-04-13T05:00:10Z', 'dateModified': '2018-04-13T05:00:10Z'}}
# Item updated: "WRAGGE."
# {'article': {'id': '70068753', 'url': '/newspaper/70068753', 'heading': "'WRAGGE.'", 'category': 'Article', 'title': {'id': '202', 'value': 'Sunbury News (Vic. : 1900 - 1910)'}, 'date': '1903-02-07', 'page': 4, 'pageSequence': 4, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/70068753'}}
# {'id': '70068753', 'url': '/newspaper/70068753', 'heading': "'WRAGGE.'", 'category': 'Article', 'title': {'id': '202', 'value': 'Sunbury News (Vic. : 1900 - 1910)'}, 'date': '1903-02-07', 'page': 4, 'pageSequence': 4, 'troveUrl': 'http://trove.nla.gov.au/ndp/del/article/70068753'}
# {'key': 'DWREESH8', 'version': 8988, 'library': {'type': 'user', 'id': 3041, 'name': 'wragge', 'links': {'alternate': {'href': 'https://www.zotero.org/wragge', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/3041/items/DWREESH8', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/wragge/items/DWREESH8', 'type': 'text/html'}}, 'meta': {'parsedDate': '1903-02-07', 'numChildren': 2}, 'data': {'key': 'DWREESH8', 'version': 8988, 'itemType': 'newspaperArticle', 'title': "'WRAGGE.'", 'creators': [], 'abstractNote': '', 'publicationTitle': 'Sunbury News (Vic. : 1900 - 1910)', 'place': 'Vic.', 'edition': '', 'date': '7 Feb 1903', 'section': '', 'pages': '4', 'language': '', 'shortTitle': '', 'ISSN': '', 'url': 'http://nla.gov.au/nla.news-article70068753', 'accessDate': '2018-08-06T04:40:24Z', 'archive': '', 'archiveLocation': '', 'libraryCatalog': 'Trove', 'callNumber': '', 'rights': '', 'extra': '', 'tags': [], 'collections': ['XXHSKJ2R'], 'relations': {}, 'dateAdded': '2018-08-06T04:40:29Z', 'dateModified': '2018-08-06T04:40:29Z'}}
# Item updated: 'WRAGGE.'
