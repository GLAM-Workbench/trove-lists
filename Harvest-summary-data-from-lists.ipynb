# %% [markdown]
# # Harvest summary data from Trove lists
#
# Using the Trove API we'll harvest some information about Trove lists and create a dataset containing the following fields:
#
# * `id` — the list identifier, you can use this to get more information about a list from either the web interface or the API
# * `title`
# * `number_items` — the number of items in the list
# * `created` — the date the list was created
# * `updated` — the date the list was last updated

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <p>If you haven't used one of these notebooks before, they're basically web pages in which you can write, edit, and run live code. They're meant to encourage experimentation, so don't feel nervous. Just try running a few cells and see what happens!.</p>
#
# <p>
#     Some tips:
#     <ul>
#         <li>Code cells have boxes around them.</li>
#         <li>To run a code cell click on the cell and then hit <b>Shift+Enter</b>. The <b>Shift+Enter</b> combo will also move you to the next cell, so it's a quick way to work through the notebook.</li>
#         <li>While a cell is running a <b>*</b> appears in the square brackets next to the cell. Once the cell has finished running the asterix will be replaced with a number.</li>
#         <li>In most cases you'll want to start from the top of notebook and work your way down running each cell in turn. Later cells might depend on the results of earlier ones.</li>
#         <li>To edit a code cell, just click on it and type stuff. Remember to run the cell once you've finished editing.</li>
#     </ul>
# </p>
# </div>

# %% [markdown]
# ## Setting up...

# %%
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import pandas as pd
from tqdm.auto import tqdm
import altair as alt
import datetime
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob import TextBlob
from operator import itemgetter
import nltk
from IPython.display import display, HTML
import time
from json import JSONDecodeError
nltk.download('stopwords')
nltk.download('punkt')

s = requests.Session()
retries = Retry(total=5, backoff_factor=1, status_forcelist=[ 500, 502, 503, 504 ])
s.mount('http://', HTTPAdapter(max_retries=retries))
s.mount('https://', HTTPAdapter(max_retries=retries))
# Out:
# [nltk_data] Downloading package stopwords to /Users/tim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/tim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Add your Trove API key

# %%
# This creates a variable called 'api_key', paste your key between the quotes
# <-- Then click the run icon 
api_key = 'YOUR API KEY'

# This displays a message with your key
print('Your API key is: {}'.format(api_key))

# %% [markdown]
# ## Set some parameters
#
# You could change the value of `q` if you only want to harvest a subset of lists.

# %%
api_url = 'http://api.trove.nla.gov.au/v2/result'
params = {
    'q': ' ',
    'zone': 'list',
    'encoding': 'json',
    'n': 100,
    's': '*',
    'key': api_key,
    'reclevel': 'full',
    'bulkHarvest': 'true'
}

# %% [markdown]
# ## Harvest the data

# %%
def get_total():
    '''
    This will enable us to make a nice progress bar...
    '''
    response = requests.get(api_url, params=params)
    data = response.json()
    return int(data['response']['zone'][0]['records']['total'])

# %%
lists = []
total = get_total()
with tqdm(total=total) as pbar:
    while params['s']:
        response = requests.get(api_url, params=params)
        try:
            data = response.json()
        except JSONDecodeError:
            print(response.text)
        else:
            records = data['response']['zone'][0]['records']
            try:
                params['s'] = records['nextStart']
            except KeyError:
                params['s'] = None
            for record in records['list']:
                lists.append({
                    'id': record['id'], 
                    'title': record.get('title', ''), 
                    'number_items': record['listItemCount'], 
                    'created': record['created'],
                    'updated': record['lastupdated']
                })
            pbar.update(100)
            time.sleep(0.2)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=95358.0), HTML(value='')))

# %% [markdown]
# ## Inspect the results

# %%
df = pd.DataFrame(lists)
df.head()
# Out:
#        id                            title  number_items  \
# 0   10000                            Smith            52
# 1  100000                          O'Grady            11
# 2  100003            Berry Street Victoria           127
# 3  100004  Angus Stuart Duff (WW1 Soldier)             8
# 4  100006                      H.U.D.U.F.S             7
#
#                 created               updated
# 0  2011-05-19T14:19:51Z  2014-05-17T08:59:09Z
# 1  2017-03-01T08:07:33Z  2017-03-01T08:07:33Z
# 2  2017-03-01T20:01:13Z  2017-03-30T23:06:01Z
# 3  2017-03-01T21:27:56Z  2017-03-01T21:27:56Z
# 4  2017-03-01T23:08:21Z  2017-03-01T23:08:21Z

# %%
df.describe()
# Out:
#        number_items
# count  95358.000000
# mean      18.663783
# std       82.783191
# min        0.000000
# 25%        1.000000
# 50%        4.000000
# 75%       12.000000
# max    10351.000000

# %% [markdown]
# ## Save the harvested data as a CSV file

# %%
csv_file = 'data/trove-lists-{}.csv'.format(datetime.datetime.now().isoformat()[:10])
df.to_csv(csv_file, index=False)
display(HTML('<a target="_blank" href="{}">Download CSV</a>'.format(csv_file)))
# Out:
# <a target="_blank" href="data/trove-lists-2020-09-22.csv">Download CSV</a>

# %% [markdown]
# ## How many items are in lists?

# %%
total_items = df['number_items'].sum()
print('There are {:,} items in {:,} lists.'.format(total_items, len(lists)))
# Out:
# There are 1,779,741 items in 95,358 lists.

# %% [markdown]
# ## What is the biggest list?

# %%
biggest = df.iloc[df['number_items'].idxmax()]
biggest
# Out:
# id                                  71461
# title           Victoria and elsewhere...
# number_items                        10351
# created              2015-04-03T11:50:51Z
# updated              2016-02-22T04:27:12Z
# Name: 74391, dtype: object

# %%
display(HTML('The biggest list is <a target="_blank" href="https://trove.nla.gov.au/list?id={}">{}</a> with {:,} items.'.format(biggest['id'], biggest['title'], biggest['number_items'])))
# Out:
# The biggest list is <a target="_blank" href="https://trove.nla.gov.au/list?id=71461">Victoria and elsewhere...</a> with 10,351 items.

# %% [markdown]
# ## When were they created?

# %%
# This makes it possible to include more than 5000 records
alt.data_transformers.enable('json', urlpath='files')
alt.Chart(df).mark_line().encode(
    x='yearmonth(created):T',
    y='count()',
    tooltip=[alt.Tooltip('yearmonth(created):T', title='Month'), alt.Tooltip('count()', title='Lists')]
).properties(width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## What words are used in the titles?

# %%
titles = df['title'].str.lower().str.cat(sep=' ')

# %%
# Generate a word cloud image
wordcloud = WordCloud(width=1200, height=800).generate(titles)
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 1199.5, 799.5, -0.5)

# %% [markdown]
# ### Word frequency

# %%
blob = TextBlob(titles)
stopwords = nltk.corpus.stopwords.words('english')
word_counts = [[word, count] for word, count in blob.lower().word_counts.items() if word not in stopwords]
word_counts = sorted(word_counts, key=itemgetter(1), reverse=True)[:25]
pd.DataFrame(word_counts).style.format({1: '{:,}'}).bar(subset=[1], color='#d65f5f').set_properties(subset=[1], **{'width': '300px'})
# Out:
# <style  type="text/css" >
#     #T_77f487e4_fcac_11ea_8510_ac87a32cd560row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.0%, transparent 61.0%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.9%, transparent 60.9%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.9%, transparent 59.9%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.0%, transparent 59.0%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 54.8%, transparent 54.8%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.6%, transparent 31.6%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.0%, transparent 30.0%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.4%, transparent 23.4%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.8%, transparent 17.8%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.9%, transparent 12.9%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.4%, transparent 12.4%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.2%, transparent 9.2%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.9%, transparent 5.9%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.0%, transparent 4.0%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.6%, transparent 3.6%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#             width:  300px;
#         }    #T_77f487e4_fcac_11ea_8510_ac87a32cd560row24_col1 {
#             width:  10em;
#              height:  80%;
#             width:  300px;
#         }</style><table id="T_77f487e4_fcac_11ea_8510_ac87a32cd560" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77f487e4_fcac_11ea_8510_ac87a32cd560level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row0_col0" class="data row0 col0" >family</td>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row0_col1" class="data row0 col1" >6,598</td>
#             </tr>
#             <tr>
#                         <th id="T_77f487e4_fcac_11ea_8510_ac87a32cd560level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row1_col0" class="data row1 col0" >soldier</td>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row1_col1" class="data row1 col1" >4,292</td>
#             </tr>
#             <tr>
#                         <th id="T_77f487e4_fcac_11ea_8510_ac87a32cd560level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row2_col0" class="data row2 col0" >ww1</td>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row2_col1" class="data row2 col1" >4,285</td>
#             </tr>
#             <tr>
#                         <th id="T_77f487e4_fcac_11ea_8510_ac87a32cd560level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row3_col0" class="data row3 col0" >list</td>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row3_col1" class="data row3 col1" >4,225</td>
#             </tr>
#             <tr>
#                         <th id="T_77f487e4_fcac_11ea_8510_ac87a32cd560level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row4_col0" class="data row4 col0" >articles</td>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row4_col1" class="data row4 col1" >4,175</td>
#             </tr>
#             <tr>
#                         <th id="T_77f487e4_fcac_11ea_8510_ac87a32cd560level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_77f487e4_fcac_11ea_8510_ac87a32cd560row5_

# %% [markdown]
# ### Bigram frequency

# %%
ngrams = [' '.join(ngram).lower() for ngram in blob.lower().ngrams(2)]
ngram_counts = pd.DataFrame(ngrams)[0].value_counts().rename_axis('ngram').reset_index(name='count')
display(ngram_counts[:25].style.format({'count': '{:,}'}).bar(subset=['count'], color='#d65f5f').set_properties(subset=['count'], **{'width': '300px'}))
# Out:
# <style  type="text/css" >
#     #T_81233694_fcac_11ea_8510_ac87a32cd560row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.1%, transparent 98.1%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.4%, transparent 97.4%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.1%, transparent 97.1%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 94.7%, transparent 94.7%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 94.2%, transparent 94.2%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.0%, transparent 22.0%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.5%, transparent 15.5%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.8%, transparent 5.8%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.6%, transparent 3.6%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.6%, transparent 3.6%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.1%, transparent 3.1%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.9%, transparent 2.9%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#             width:  300px;
#         }    #T_81233694_fcac_11ea_8510_ac87a32cd560row24_col1 {
#             width:  10em;
#              height:  80%;
#             width:  300px;
#         }</style><table id="T_81233694_fcac_11ea_8510_ac87a32cd560" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ngram</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_81233694_fcac_11ea_8510_ac87a32cd560level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row0_col0" class="data row0 col0" >ww1 soldier</td>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row0_col1" class="data row0 col1" >3,957</td>
#             </tr>
#             <tr>
#                         <th id="T_81233694_fcac_11ea_8510_ac87a32cd560level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row1_col0" class="data row1 col0" >list of</td>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row1_col1" class="data row1 col1" >3,886</td>
#             </tr>
#             <tr>
#                         <th id="T_81233694_fcac_11ea_8510_ac87a32cd560level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row2_col0" class="data row2 col0" >of articles</td>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row2_col1" class="data row2 col1" >3,858</td>
#             </tr>
#             <tr>
#                         <th id="T_81233694_fcac_11ea_8510_ac87a32cd560level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row3_col0" class="data row3 col0" >soldier list</td>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row3_col1" class="data row3 col1" >3,847</td>
#             </tr>
#             <tr>
#                         <th id="T_81233694_fcac_11ea_8510_ac87a32cd560level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row4_col0" class="data row4 col0" >in trove</td>
#                         <td id="T_81233694_fcac_11ea_8510_ac87a32cd560row4_col1" class="data row4 col1" >3,755</td>
#             </tr>
#             <tr>
#                         <th id="T_81233694_fcac_11ea_8510_ac87a32cd560level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_81233694_fcac_11ea_8

# %% [markdown]
# ### Trigram frequency

# %%
ngrams = [' '.join(ngram).lower() for ngram in blob.lower().ngrams(3)]
ngram_counts = pd.DataFrame(ngrams)[0].value_counts().rename_axis('ngram').reset_index(name='count')
display(ngram_counts[:25].style.format({'count': '{:,}'}).bar(subset=['count'], color='#d65f5f').set_properties(subset=['count'], **{'width': '300px'}))
# Out:
# <style  type="text/css" >
#     #T_8b655150_fcac_11ea_8510_ac87a32cd560row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.8%, transparent 99.8%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.8%, transparent 96.8%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.7%, transparent 96.7%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 92.5%, transparent 92.5%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.2%, transparent 5.2%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.9%, transparent 2.9%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.2%, transparent 1.2%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#             width:  300px;
#         }    #T_8b655150_fcac_11ea_8510_ac87a32cd560row24_col1 {
#             width:  10em;
#              height:  80%;
#             width:  300px;
#         }</style><table id="T_8b655150_fcac_11ea_8510_ac87a32cd560" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ngram</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b655150_fcac_11ea_8510_ac87a32cd560level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row0_col0" class="data row0 col0" >list of articles</td>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row0_col1" class="data row0 col1" >3,847</td>
#             </tr>
#             <tr>
#                         <th id="T_8b655150_fcac_11ea_8510_ac87a32cd560level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row1_col0" class="data row1 col0" >soldier list of</td>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row1_col1" class="data row1 col1" >3,840</td>
#             </tr>
#             <tr>
#                         <th id="T_8b655150_fcac_11ea_8510_ac87a32cd560level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row2_col0" class="data row2 col0" >articles in trove</td>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row2_col1" class="data row2 col1" >3,728</td>
#             </tr>
#             <tr>
#                         <th id="T_8b655150_fcac_11ea_8510_ac87a32cd560level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row3_col0" class="data row3 col0" >of articles in</td>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row3_col1" class="data row3 col1" >3,721</td>
#             </tr>
#             <tr>
#                         <th id="T_8b655150_fcac_11ea_8510_ac87a32cd560level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row4_col0" class="data row4 col0" >ww1 soldier list</td>
#                         <td id="T_8b655150_fcac_11ea_8510_ac87a32cd560row4_col1" class="data row4 col1" >3,563</td>
#             </tr>
#             <tr>
#                         <th id="T_8b655150_fcac_11ea_8510_ac87a32cd560level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id=

# %% [markdown]
# ----
#
# Created by [Tim Sherratt](https://timsherratt.org/) for the [GLAM Workbench](https://glam-workbench.github.io/).
